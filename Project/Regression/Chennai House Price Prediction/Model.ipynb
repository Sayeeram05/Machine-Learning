# %%
import numpy as np
import pandas as pd

# %%
Df = pd.read_csv("Chennai houseing sale.csv")
Df.head()
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2  P01812       Adyar       909  04-02-2012             70        1.0
# 3  P05346   Velachery      1855  13-03-2010             14        3.0
# 4  P06210  Karapakkam      1226  05-10-2009             84        1.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  ... UTILITY_AVAIL  STREET MZZONE  \
# 0         1.0       3  AbNormal        Yes  ...        AllPub   Paved      A
# 1         1.0       5  AbNormal         No  ...        AllPub  Gravel     RH
# 2         1.0       3  AbNormal        Yes  ...           ELO  Gravel     RL
# 3         2.0       5    Family         No  ...       NoSewr    Paved      I
# 4         1.0       3  AbNormal        Yes  ...        AllPub  Gravel      C
#
#   QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE
# ...

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   object
#  1   AREA           7109 non-null   object
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   object
#  4   DIST_MAINROAD  7109 non-null   int64
#  5   N_BEDROOM      7108 non-null   float64
#  6   N_BATHROOM     7104 non-null   float64
#  7   N_ROOM         7109 non-null   int64
#  8   SALE_COND      7109 non-null   object
#  9   PARK_FACIL     7109 non-null   object
#  10  DATE_BUILD     7109 non-null   object
#  11  BUILDTYPE      7109 non-null   object
#  12  UTILITY_AVAIL  7109 non-null   object
#  13  STREET         7109 non-null   object
#  14  MZZONE         7109 non-null   object
#  15  QS_ROOMS       7109 non-null   float64
#  16  QS_BATHROOM    7109 non-null   float64
# ...

# %%
Df.describe()
# Out:
#           INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM       N_ROOM  \
# count  7109.000000    7109.000000  7108.000000  7104.000000  7109.000000
# mean   1382.073006      99.603179     1.637029     1.213260     3.688704
# std     457.410902      57.403110     0.802902     0.409639     1.019099
# min     500.000000       0.000000     1.000000     1.000000     2.000000
# 25%     993.000000      50.000000     1.000000     1.000000     3.000000
# 50%    1373.000000      99.000000     1.000000     1.000000     4.000000
# 75%    1744.000000     148.000000     2.000000     1.000000     4.000000
# max    2500.000000     200.000000     4.000000     2.000000     6.000000
#
#           QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL        REG_FEE  \
# count  7109.000000  7109.000000  7109.000000  7061.000000    7109.000000
# mean      3.517471     3.507244     3.485300     3.503254  376938.330708
# std       0.891972     0.897834     0.887266     0.527223  143070.662010
# ...

# %%
for i in Df.columns:
    print(i,":",Df[i].unique(),end="\n\n")
# Out:
# PRT_ID : ['P03210' 'P09411' 'P01812' ... 'P09594' 'P06508' 'P09794']
#
# AREA : ['Karapakkam' 'Anna Nagar' 'Adyar' 'Velachery' 'Chrompet' 'KK Nagar'
#  'TNagar' 'T Nagar' 'Chrompt' 'Chrmpet' 'Karapakam' 'Ana Nagar' 'Chormpet'
#  'Adyr' 'Velchery' 'Ann Nagar' 'KKNagar']
#
# INT_SQFT : [1004 1986  909 ...  688 2051  598]
#
# DATE_SALE : ['04-05-2011' '19-12-2006' '04-02-2012' ... '28-03-2014' '25-08-2006'
#  '13-07-2005']
#
# DIST_MAINROAD : [131  26  70  14  84  36 137 176 175  74  78 143  83 157 148 134  69 168
#   53  96 114 100 111 105  29  59 185 138 173  15 117  16 130  46 180  52
#   86  49 113 189  28  51  19 167 126  75 154  25 187 200  32  11  23  13
#   58  89  48  39 177 116  41 192  72  24  43  85 171 149  73  62 145 125
#  121 129   6 103   8  50  67   0 147  71  34 178 106 144 135  38  40 142
#   79  20  99 166  63  44  60  90 169  10 122 108  98  57 104  17   1 109
#  164 136  97  37   9 181  93  81 193  95 196 141 158 174  94 124  82  76
# ...

# %%
Df["DATE_BUILD"] = pd.to_datetime(Df["DATE_BUILD"],format="%d-%m-%Y")
Df["DATE_SALE"] = pd.to_datetime(Df["DATE_SALE"],format="%d-%m-%Y")

# %%
Df["DATE_SALE"].dt.year.head()
# Out:
# 0    2011
# 1    2006
# 2    2012
# 3    2010
# 4    2009
# Name: DATE_SALE, dtype: int32

# %%
Df["DATE_BUILD"].dt.year.head()
# Out:
# 0    1967
# 1    1995
# 2    1992
# 3    1988
# 4    1979
# Name: DATE_BUILD, dtype: int32

# %%
Df["PROPERTY_AGE"] = Df["DATE_SALE"].dt.year - Df["DATE_BUILD"].dt.year

# %%
Df.head()
# Out:
#    PRT_ID        AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004 2011-05-04            131        1.0
# 1  P09411  Anna Nagar      1986 2006-12-19             26        2.0
# 2  P01812       Adyar       909 2012-02-04             70        1.0
# 3  P05346   Velachery      1855 2010-03-13             14        3.0
# 4  P06210  Karapakkam      1226 2009-10-05             84        1.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  ...  STREET MZZONE QS_ROOMS  \
# 0         1.0       3  AbNormal        Yes  ...   Paved      A      4.0
# 1         1.0       5  AbNormal         No  ...  Gravel     RH      4.9
# 2         1.0       3  AbNormal        Yes  ...  Gravel     RL      4.1
# 3         2.0       5    Family         No  ...   Paved      I      4.7
# 4         1.0       3  AbNormal        Yes  ...  Gravel      C      3.0
#
#   QS_BATHROOM QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE  \
# ...

# %%
Df["AREA"].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'TNagar', 'T Nagar', 'Chrompt', 'Chrmpet', 'Karapakam',
#        'Ana Nagar', 'Chormpet', 'Adyr', 'Velchery', 'Ann Nagar',
#        'KKNagar'], dtype=object)

# %%
Df.loc[Df["AREA"]=='KK Nagar',"AREA"] = "KKNagar"
Df.loc[Df["AREA"].isin(['Chormpet',"Chrmpet","Chrompt"]),"AREA"] = "Chrompet"
Df.loc[Df["AREA"].isin(['Ana Nagar',"Ann Nagar"]),"AREA"] = "Anna Nagar"
Df.loc[Df["AREA"] == "Adyr","AREA"] = "Adyar"
Df.loc[Df["AREA"] == "T Nagar","AREA"] = "TNagar"
Df.loc[Df["AREA"] == "Velchery","AREA"] = "Velachery"
Df.loc[Df["AREA"] == "Karapakam","AREA"] = "Karapakkam"

# %%
Df["AREA"].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KKNagar', 'TNagar'], dtype=object)

# %%
Df["SALE_COND"].unique()
# Out:
# array(['AbNormal', 'Family', 'Partial', 'AdjLand', 'Normal Sale',
#        'Ab Normal', 'Partiall', 'Adj Land', 'PartiaLl'], dtype=object)

# %%
Df.loc[Df["SALE_COND"] == "Ab Normal","SALE_COND"] = "AbNormal"
Df.loc[Df["SALE_COND"].isin(["Partiall","PartiaLl"]),"SALE_COND"] = "Partial"
Df.loc[Df["SALE_COND"] == "Adj Land","SALE_COND"] = "AdjLand"

# %%
Df["SALE_COND"].unique()
# Out:
# array(['AbNormal', 'Family', 'Partial', 'AdjLand', 'Normal Sale'],
#       dtype=object)

# %%
Df["PARK_FACIL"].unique()
# Out:
# array(['Yes', 'No', 'Noo'], dtype=object)

# %%
Df.loc[Df["PARK_FACIL"] == "Noo","PARK_FACIL"] = "No"

# %%
Df["PARK_FACIL"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
Df["BUILDTYPE"].unique()
# Out:
# array(['Commercial', 'Others', 'Other', 'House', 'Comercial'],
#       dtype=object)

# %%
Df.loc[Df["BUILDTYPE"] == "Other","BUILDTYPE"] = "Others"
Df.loc[Df["BUILDTYPE"] == "Commercial","BUILDTYPE"] = "Comercial"

# %%
Df["BUILDTYPE"].unique()
# Out:
# array(['Comercial', 'Others', 'House'], dtype=object)

# %%
Df["UTILITY_AVAIL"].unique()
# Out:
# array(['AllPub', 'ELO', 'NoSewr ', 'NoSeWa', 'All Pub'], dtype=object)

# %%
Df.loc[Df["UTILITY_AVAIL"] == "All Pub","UTILITY_AVAIL"] = "AllPub"

# %%
Df["UTILITY_AVAIL"].unique()
# Out:
# array(['AllPub', 'ELO', 'NoSewr ', 'NoSeWa'], dtype=object)

# %%
Df["STREET"].unique()
# Out:
# array(['Paved', 'Gravel', 'No Access', 'Pavd', 'NoAccess'], dtype=object)

# %%
Df.loc[Df["STREET"] == "Pavd","STREET"] = "Paved"
Df.loc[Df["STREET"] == "No Access","STREET"] = "NoAccess"

# %%
Df["STREET"].unique()
# Out:
# array(['Paved', 'Gravel', 'NoAccess'], dtype=object)

# %%
for i in Df.columns:
    print(i,":",Df[i].unique(),end="\n\n")
# Out:
# PRT_ID : ['P03210' 'P09411' 'P01812' ... 'P09594' 'P06508' 'P09794']
#
# AREA : ['Karapakkam' 'Anna Nagar' 'Adyar' 'Velachery' 'Chrompet' 'KKNagar'
#  'TNagar']
#
# INT_SQFT : [1004 1986  909 ...  688 2051  598]
#
# DATE_SALE : <DatetimeArray>
# ['2011-05-04 00:00:00', '2006-12-19 00:00:00', '2012-02-04 00:00:00',
#  '2010-03-13 00:00:00', '2009-10-05 00:00:00', '2014-09-11 00:00:00',
#  '2007-04-05 00:00:00', '2006-03-13 00:00:00', '2011-04-06 00:00:00',
#  '2006-06-22 00:00:00',
#  ...
#  '2009-03-22 00:00:00', '2012-04-16 00:00:00', '2014-07-04 00:00:00',
#  '2013-09-22 00:00:00', '2014-03-24 00:00:00', '2005-09-11 00:00:00',
#  '2007-11-15 00:00:00', '2014-03-28 00:00:00', '2006-08-25 00:00:00',
#  '2005-07-13 00:00:00']
# Length: 2798, dtype: datetime64[ns]
#
# DIST_MAINROAD : [131  26  70  14  84  36 137 176 175  74  78 143  83 157 148 134  69 168
#   53  96 114 100 111 105  29  59 185 138 173  15 117  16 130  46 180  52
# ...

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   object
#  1   AREA           7109 non-null   object
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   datetime64[ns]
#  4   DIST_MAINROAD  7109 non-null   int64
#  5   N_BEDROOM      7108 non-null   float64
#  6   N_BATHROOM     7104 non-null   float64
#  7   N_ROOM         7109 non-null   int64
#  8   SALE_COND      7109 non-null   object
#  9   PARK_FACIL     7109 non-null   object
#  10  DATE_BUILD     7109 non-null   datetime64[ns]
#  11  BUILDTYPE      7109 non-null   object
#  12  UTILITY_AVAIL  7109 non-null   object
#  13  STREET         7109 non-null   object
#  14  MZZONE         7109 non-null   object
#  15  QS_ROOMS       7109 non-null   float64
#  16  QS_BATHROOM    7109 non-null   float64
# ...

# %%
Data = {}

# %%
for col in Df.columns:
    if Df[col].dtype == "object":  
        Df[col], Data[col] = pd.factorize(Df[col],sort=True)

# %%
# Data

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   int64
#  1   AREA           7109 non-null   int64
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   datetime64[ns]
#  4   DIST_MAINROAD  7109 non-null   int64
#  5   N_BEDROOM      7108 non-null   float64
#  6   N_BATHROOM     7104 non-null   float64
#  7   N_ROOM         7109 non-null   int64
#  8   SALE_COND      7109 non-null   int64
#  9   PARK_FACIL     7109 non-null   int64
#  10  DATE_BUILD     7109 non-null   datetime64[ns]
#  11  BUILDTYPE      7109 non-null   int64
#  12  UTILITY_AVAIL  7109 non-null   int64
#  13  STREET         7109 non-null   int64
#  14  MZZONE         7109 non-null   int64
#  15  QS_ROOMS       7109 non-null   float64
#  16  QS_BATHROOM    7109 non-null   float64
# ...

# %%
Df.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# PROPERTY_AGE      0
# dtype: int64

# %%
Df.describe()
# Out:
#             PRT_ID         AREA     INT_SQFT                      DATE_SALE  \
# count  7109.000000  7109.000000  7109.000000                           7109
# mean   3554.000000     2.959347  1382.073006  2010-04-06 19:41:07.688845056
# min       0.000000     0.000000   500.000000            2004-01-16 00:00:00
# 25%    1777.000000     2.000000   993.000000            2008-10-17 00:00:00
# 50%    3554.000000     3.000000  1373.000000            2010-05-03 00:00:00
# 75%    5331.000000     4.000000  1744.000000            2011-09-15 00:00:00
# max    7108.000000     6.000000  2500.000000            2015-02-17 00:00:00
# std    2052.335864     1.837797   457.410902                            NaN
#
#        DIST_MAINROAD    N_BEDROOM   N_BATHROOM       N_ROOM    SALE_COND  \
# count    7109.000000  7108.000000  7104.000000  7109.000000  7109.000000
# mean       99.603179     1.637029     1.213260     3.688704     2.003939
# ...

# %%
Df["N_BEDROOM"].mode()
# Out:
# 0    1.0
# Name: N_BEDROOM, dtype: float64

# %%
Df["N_BATHROOM"].mode()
# Out:
# 0    1.0
# Name: N_BATHROOM, dtype: float64

# %%
Df["QS_OVERALL"].mode()
# Out:
# 0    3.54
# Name: QS_OVERALL, dtype: float64

# %%
Df.loc[Df["N_BEDROOM"].isnull()]
# Out:
#       PRT_ID  AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 4060     728     1      1556 2013-01-16            181        NaN         1.0
#
#       N_ROOM  SALE_COND  PARK_FACIL  ... STREET  MZZONE  QS_ROOMS  \
# 4060       4          4           0  ...      1       5       4.8
#
#       QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE  \
# 4060          2.7         2.0       3.155   313136  107978     10797790
#
#       PROPERTY_AGE
# 4060            27
#
# [1 rows x 23 columns]

# %%
Df["N_BEDROOM"].fillna(1.0,inplace=True)
# Out:
# C:\Users\SAYEERAM\AppData\Local\Temp\ipykernel_18312\625710121.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Df["N_BEDROOM"].fillna(1.0,inplace=True)

# %%
Df.loc[Df["N_BATHROOM"].isnull()]
# Out:
#       PRT_ID  AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 70      3723     1      1589 2010-03-22             39        1.0         NaN
# 5087     923     2      1016 2012-08-02            105        1.0         NaN
# 6134     922     2       916 2012-08-02            173        1.0         NaN
# 6371     825     2      1035 2012-11-06             90        1.0         NaN
# 6535    6509     1      1864 2007-03-05            184        2.0         NaN
#
#       N_ROOM  SALE_COND  PARK_FACIL  ... STREET  MZZONE  QS_ROOMS  \
# 70         4          4           0  ...      0       4       2.1
# 5087       3          0           1  ...      0       5       3.2
# 6134       3          3           1  ...      2       4       3.4
# 6371       3          4           0  ...      1       5       2.3
# 6535       5          2           1  ...      2       5       3.3
#
#       QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE  \
# ...

# %%
Df["N_BATHROOM"].fillna(1.0,inplace=True)
# Out:
# C:\Users\SAYEERAM\AppData\Local\Temp\ipykernel_18312\222100978.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Df["N_BATHROOM"].fillna(1.0,inplace=True)

# %%
Df["QS_OVERALL"].fillna(3.54,inplace=True)
# Out:
# C:\Users\SAYEERAM\AppData\Local\Temp\ipykernel_18312\4182255435.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Df["QS_OVERALL"].fillna(3.54,inplace=True)

# %%
Df.isnull().sum()
# Out:
# PRT_ID           0
# AREA             0
# INT_SQFT         0
# DATE_SALE        0
# DIST_MAINROAD    0
# N_BEDROOM        0
# N_BATHROOM       0
# N_ROOM           0
# SALE_COND        0
# PARK_FACIL       0
# DATE_BUILD       0
# BUILDTYPE        0
# UTILITY_AVAIL    0
# STREET           0
# MZZONE           0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# REG_FEE          0
# COMMIS           0
# SALES_PRICE      0
# PROPERTY_AGE     0
# dtype: int64

# %%
for col in Df.columns:
    if(Df[col].dtype == 'float64'):
        Df[col] = Df[col].astype(int)

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   int64
#  1   AREA           7109 non-null   int64
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   datetime64[ns]
#  4   DIST_MAINROAD  7109 non-null   int64
#  5   N_BEDROOM      7109 non-null   int32
#  6   N_BATHROOM     7109 non-null   int32
#  7   N_ROOM         7109 non-null   int64
#  8   SALE_COND      7109 non-null   int64
#  9   PARK_FACIL     7109 non-null   int64
#  10  DATE_BUILD     7109 non-null   datetime64[ns]
#  11  BUILDTYPE      7109 non-null   int64
#  12  UTILITY_AVAIL  7109 non-null   int64
#  13  STREET         7109 non-null   int64
#  14  MZZONE         7109 non-null   int64
#  15  QS_ROOMS       7109 non-null   int32
#  16  QS_BATHROOM    7109 non-null   int32
# ...

# %%
Df.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE', 'PROPERTY_AGE'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

# %%
for col in Df.columns:
    plt.figure(figsize=(6,4))  
    sns.scatterplot(y=Df[col], x=Df["SALES_PRICE"])
    plt.ylabel(col)
    plt.xlabel("SALES_PRICE")
    plt.title(f"Scatter plot of {col} vs SALES_PRICE")
    plt.show()

# %%
Df.iloc[:,:].corr()
# Out:
#                  PRT_ID      AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  \
# PRT_ID         1.000000  0.129180  0.114991  -0.975544      -0.011866
# AREA           0.129180  1.000000  0.351331  -0.187460      -0.015105
# INT_SQFT       0.114991  0.351331  1.000000  -0.127499       0.002022
# DATE_SALE     -0.975544 -0.187460 -0.127499   1.000000       0.012818
# DIST_MAINROAD -0.011866 -0.015105  0.002022   0.012818       1.000000
# N_BEDROOM      0.166040  0.361847  0.786263  -0.189172      -0.002723
# N_BATHROOM     0.083638  0.222176  0.515290  -0.106102       0.001850
# N_ROOM         0.103123  0.279363  0.951279  -0.112445       0.002301
# SALE_COND     -0.003208 -0.007565  0.006969   0.002632       0.004367
# PARK_FACIL     0.004354  0.010383  0.004618  -0.005437      -0.009448
# DATE_BUILD    -0.201553 -0.209086 -0.009612   0.226859       0.005718
# BUILDTYPE     -0.019329 -0.009517 -0.006329   0.019192      -0.014235
# ...

# %%
correlation_with_target = Df.corr()["SALES_PRICE"].abs().sort_values(ascending=False)
print(correlation_with_target)
# Out:
# SALES_PRICE      1.000000
# REG_FEE          0.878148
# COMMIS           0.626275
# INT_SQFT         0.612125
# N_ROOM           0.602760
# BUILDTYPE        0.436276
# MZZONE           0.427789
# N_BEDROOM        0.330987
# PARK_FACIL       0.146428
# PROPERTY_AGE     0.118842
# DATE_BUILD       0.116118
# N_BATHROOM       0.108834
# STREET           0.042652
# SALE_COND        0.030732
# QS_BATHROOM      0.019469
# AREA             0.019138
# PRT_ID           0.019078
# DIST_MAINROAD    0.018783
# QS_ROOMS         0.016059
# UTILITY_AVAIL    0.015913
# QS_BEDROOM       0.015044
# QS_OVERALL       0.012567
# DATE_SALE        0.000047
# Name: SALES_PRICE, dtype: float64

# %%
plt.figure(figsize=(20,14))
sns.heatmap(Df.iloc[:,:].corr(),annot=True,cmap=sns.color_palette("flare"))
plt.title('Heatmap of the Data')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
Df.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE', 'PROPERTY_AGE'],
#       dtype='object')

# %%
X = Df.loc[:,["REG_FEE","COMMIS","INT_SQFT","N_ROOM","BUILDTYPE","MZZONE","N_BEDROOM","PARK_FACIL","PROPERTY_AGE","N_BATHROOM","STREET","SALE_COND"]]

# %%
# X = Df.loc[:,['AREA', 'INT_SQFT', 'DIST_MAINROAD', 'N_BEDROOM','N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL','BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS','QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS', 'PROPERTY_AGE']]

# %%
X.head()
# Out:
#    AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  SALE_COND  \
# 0     4      1004            131          1           1       3          0
# 1     1      1986             26          2           1       5          0
# 2     0       909             70          1           1       3          0
# 3     6      1855             14          3           2       5          2
# 4     4      1226             84          1           1       3          0
#
#    PARK_FACIL  BUILDTYPE  UTILITY_AVAIL  STREET  MZZONE  QS_ROOMS  \
# 0           1          0              0       2       0         4
# 1           0          0              0       0       3         4
# 2           1          0              1       0       4         4
# 3           0          2              3       2       2         4
# 4           1          2              0       0       1         3
#
#    QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  PROPERTY_AGE
# ...

# %%
y = Df.loc[:,"SALES_PRICE"]

# %%
X_Train,X_Test,y_Train,y_Test = train_test_split(X,y,shuffle=True,test_size=0.25)

# %%
X_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5331 entries, 5598 to 4685
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AREA           5331 non-null   int64
#  1   INT_SQFT       5331 non-null   int64
#  2   DIST_MAINROAD  5331 non-null   int64
#  3   N_BEDROOM      5331 non-null   int32
#  4   N_BATHROOM     5331 non-null   int32
#  5   N_ROOM         5331 non-null   int64
#  6   SALE_COND      5331 non-null   int64
#  7   PARK_FACIL     5331 non-null   int64
#  8   BUILDTYPE      5331 non-null   int64
#  9   UTILITY_AVAIL  5331 non-null   int64
#  10  STREET         5331 non-null   int64
#  11  MZZONE         5331 non-null   int64
#  12  QS_ROOMS       5331 non-null   int32
#  13  QS_BATHROOM    5331 non-null   int32
#  14  QS_BEDROOM     5331 non-null   int32
#  15  QS_OVERALL     5331 non-null   int32
#  16  REG_FEE        5331 non-null   int64
#  17  COMMIS         5331 non-null   int64
# ...

# %%
plt.figure(figsize=(20,14))
sns.heatmap(X.corr(),annot=True,cmap=sns.color_palette("flare"))
plt.title('Heatmap of the Data')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
LR.fit(X_Train,y_Train)
# Out:
# LinearRegression()

# %%
Prediction = LR.predict(X_Test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
import math

# %%
print("Mean Absolute Error : ",mean_absolute_error(y_Test,Prediction))
print("Mean Square Error : ",mean_squared_error(y_Test,Prediction))
print("Root Mean Square Error : ",math.sqrt(mean_squared_error(y_Test,Prediction)))
# Out:
# Mean Absolute Error :  1040333.5024164307
# Mean Square Error :  1689168952590.3765
# Root Mean Square Error :  1299680.3270767687

# %%
Df['SALES_PRICE'].min()
# Out:
# 2156875

# %%
Df['SALES_PRICE'].max()
# Out:
# 23667340

# %%
sns.scatterplot(x=Prediction,y=y_Test)
plt.xlabel("Prediction")
plt.title("Evaluation")
# Out:
# Text(0.5, 1.0, 'Evaluation')
